# %% [markdown]
# <a href="https://colab.research.google.com/github/SiddharthJain02/Sensex-Trend-Predictor/blob/master/Sensex_predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import random as rnd
from sklearn.model_selection import train_test_split
from __future__ import absolute_import, division, print_function

import pathlib

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9bfebebe-5a8d-4fc3-b07c-3f8f4b7afbb8" name="files[]" multiple disabled />
#      <output id="result-9bfebebe-5a8d-4fc3-b07c-3f8f4b7afbb8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CSVForDate.csv to CSVForDate.csv

# %%
import io
sensex_df = pd.read_csv(io.BytesIO(uploaded['CSVForDate.csv']))

# %%
from google.colab import files
uploaded = files.upload()
prediction_df = pd.read_csv(io.BytesIO(uploaded['predictions.csv']))
# Out:
#      <input type="file" id="files-95c4db9e-7b16-4052-8447-24086b0800a8" name="files[]" multiple disabled />
#      <output id="result-95c4db9e-7b16-4052-8447-24086b0800a8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-0a9a13f53386> in <module>()
#       1 from google.colab import files
#       2 uploaded = files.upload()
# ----> 3 prediction_df = pd.read_csv(io.BytesIO(uploaded['predictions.csv']))
#
# KeyError: 'predictions.csv'

# %%
sensex_df['Stable_gov'][0:182] = 0
sensex_df['Stable_gov'][182:2157] = 1
sensex_df['Stable_gov'][2157:2459] = 0
sensex_df['Stable_gov'][2459:3524] = 1
sensex_df['Stable_gov'][3524:3970] = 0
sensex_df['Stable_gov'][3970:9243] = 1

prediction_df['Stable_gov'] = 1
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
sensex_df['Gdp_growth'][0:223] = -5.2
sensex_df['Gdp_growth'][223:411] = 7.17
sensex_df['Gdp_growth'][411:587] = 5.63
sensex_df['Gdp_growth'][587:784] = 2.92
sensex_df['Gdp_growth'][784:974] = 7.85
sensex_df['Gdp_growth'][974:1171] = 3.96
sensex_df['Gdp_growth'][1171:1371] = 4.16
sensex_df['Gdp_growth'][1371:1574] = 4.31
sensex_df['Gdp_growth'][1574:1800] = 3.53
sensex_df['Gdp_growth'][1800:2011] = 10.16
sensex_df['Gdp_growth'][2011:2222] = 6.13
sensex_df['Gdp_growth'][2222:2410] = 5.29
sensex_df['Gdp_growth'][2410:2626] = 1.43
sensex_df['Gdp_growth'][2626:2816] = 5.36
sensex_df['Gdp_growth'][2816:3039] = 5.68
sensex_df['Gdp_growth'][3039:3264] = 6.39
sensex_df['Gdp_growth'][3264:3497] = 7.29
sensex_df['Gdp_growth'][3497:3738] = 7.97
sensex_df['Gdp_growth'][3738:3982] = 4.30
sensex_df['Gdp_growth'][3982:4230] = 6.68
sensex_df['Gdp_growth'][4230:4474] = 8.00
sensex_df['Gdp_growth'][4474:4726] = 4.15
sensex_df['Gdp_growth'][4726:4974] = 5.39
sensex_df['Gdp_growth'][4974:5225] = 3.88
sensex_df['Gdp_growth'][5225:5484] = 7.97
sensex_df['Gdp_growth'][5484:5981] = 7.05
sensex_df['Gdp_growth'][5981:6231] = 9.48
sensex_df['Gdp_growth'][6231:6481] = 9.57
sensex_df['Gdp_growth'][6481:6724] = 9.32
sensex_df['Gdp_growth'][6724:6968] = 6.72
sensex_df['Gdp_growth'][6968:7222] = 8.59
sensex_df['Gdp_growth'][7222:7476] = 8.91
sensex_df['Gdp_growth'][7476:7730] = 6.69
sensex_df['Gdp_growth'][7730:7971] = 4.47
sensex_df['Gdp_growth'][7971:8214] = 4.74
sensex_df['Gdp_growth'][8214:8461] = 7.41
sensex_df['Gdp_growth'][8461:8741] = 8.15
sensex_df['Gdp_growth'][8741:8962] = 7.11
sensex_df['Gdp_growth'][8962:9242] = 6.68

prediction_df['Gdp_growth'][0:300] = 7.11
prediction_df['Gdp_growth'][300:665] = 7.45
prediction_df['Gdp_growth'][665:1003] = 7.74
prediction_df['Gdp_growth'][1003:1368] = 7.73
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
sensex_df['Bank_rate'][0:456] = 9
sensex_df['Bank_rate'][456:2469] = 10
sensex_df['Bank_rate'][2469:2525] = 11
sensex_df['Bank_rate'][2525:3747] = 12
sensex_df['Bank_rate'][3747:3792] = 11
sensex_df['Bank_rate'][3792:3873] = 9
sensex_df['Bank_rate'][3873:3931] = 11
sensex_df['Bank_rate'][3931:3971] = 10.5
sensex_df['Bank_rate'][3971:3982] = 10
sensex_df['Bank_rate'][3982:3997] = 9
sensex_df['Bank_rate'][3997:4205] = 8
sensex_df['Bank_rate'][4205:4474] = 7
sensex_df['Bank_rate'][4474:4550] = 8
sensex_df['Bank_rate'][4550:4695] = 7.5
sensex_df['Bank_rate'][4695:4705] = 7
sensex_df['Bank_rate'][4705:4865] = 6.5
sensex_df['Bank_rate'][4685:5119] = 6.25
sensex_df['Bank_rate'][5119:7221] = 6
sensex_df['Bank_rate'][7221:7470] = 9.5
sensex_df['Bank_rate'][7470:7719] = 8.5
sensex_df['Bank_rate'][7719:7969] = 9
sensex_df['Bank_rate'][7969:8215] = 8.5
sensex_df['Bank_rate'][8215:8460] = 7.75
sensex_df['Bank_rate'][8460:8708] = 7
sensex_df['Bank_rate'][8708:9083] = 6.75
sensex_df['Bank_rate'][9083:9168] = 6.5
sensex_df['Bank_rate'][9168:9206] = 6.25
sensex_df['Bank_rate'][9206:9242] = 6

prediction_df['Bank_rate'][0:5] = 6
prediction_df['Bank_rate'][5:1368] = 5.75
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
sensex_df.describe()
# Out:
#         Unnamed: 0  Unnamed: 0.1  ...    Gdp_class    Bank_rate
# count  9242.000000   9242.000000  ...  9242.000000  9242.000000
# mean   4620.500000   4620.500000  ...     2.503246     8.496862
# std    2668.079928   2668.079928  ...     0.664495     2.077238
# min       0.000000      0.000000  ...     0.000000     6.000000
# 25%    2310.250000   2310.250000  ...     2.000000     6.250000
# 50%    4620.500000   4620.500000  ...     3.000000     8.500000
# 75%    6930.750000   6930.750000  ...     3.000000    10.000000
# max    9241.000000   9241.000000  ...     3.000000    12.000000
#
# [8 rows x 8 columns]

# %%
sensex_df.drop(['Unnamed: 0'],axis=1)
# Out:
#       Unnamed: 0.1           Date  ...  Gdp_class  Bank_rate
# 0                0   3-April-1979  ...          0        9.0
# 1                1   4-April-1979  ...          0        9.0
# 2                2   6-April-1979  ...          0        9.0
# 3                3   7-April-1979  ...          0        9.0
# 4                4   9-April-1979  ...          0        9.0
# 5                5  11-April-1979  ...          0        9.0
# 6                6  12-April-1979  ...          0        9.0
# 7                7  14-April-1979  ...          0        9.0
# 8                8  17-April-1979  ...          0        9.0
# 9                9  18-April-1979  ...          0        9.0
# 10              10  19-April-1979  ...          0        9.0
# 11              11  20-April-1979  ...          0        9.0
# 12              12  21-April-1979  ...          0        9.0
# 13              13  23-April-1979  ...          0        9.0
# 14              14  24-April-1979  ...          0        9.0
# 15              15  25-April-1979  ...          0        9.0
# 16              16  26-April-1979  ...          0        9.0
# 17              17  27-April-1979  ...          0        9.0
# 18              18     2-May-1979  ...          0        9.0
# 19              19     3-May-1979  ...          0        9.0
# 20              20     4-May-1979  ...          0        9.0
# 21              21     5-May-1979  ...          0        9.0
# 22              22     7-May-1979  ...          0        9.0
# 23              23     8-May-1979  ...          0        9.0
# 24              24     9-May-1979  ...          0        9.0
# 25              25    10-May-1979  ...          0        9.0
# 26              26    11-May-1979  ...          0        9.0
# 27              27    15-May-1979  ...          0        9.0
# 28              28    16-May-1979  ...          0        9.0
# 29              29    17-May-1979  ...          0        9.0
# ...            ...            ...  ...        ...        ...
# 9212          9212  16-April-2019  ...          3        6.0
# 9213          9213  18-April-2019  ...          3        6.0
# 9214          9214  22-April-2019  ...          3        6.0
# 9215          9215  23-April-2019  ...          3        6.0
# 9216          9216  24-April-2019  ...          3        6.0
# 9217          9217  25-April-2019  ...          3        6.0
# 9218          9218  26-April-2019  ...          3        6.0
# 9219          9219  30-April-2019  ...          3        6.0
# 9220          9220     2-May-2019  ...          3        6.0
# 9221          9221     3-May-2019  ...          3        6.0
# 9222          9222     6-May-2019  ...          3        6.0
# 9223          9223     7-May-2019  ...          3        6.0
# 9224          9224     8-May-2019  ...          3        6.0
# 9225          9225     9-May-2019  ...          3        6.0
# 9226          9226    10-May-2019  ...          3        6.0
# 9227          9227    13-May-2019  ...          3        6.0
# 9228          9228    14-May-2019  ...          3        6.0
# 9229          9229    15-May-2019  ...          3        6.0
# 9230          9230    16-May-2019  ...          3        6.0
# 9231          9231    17-May-2019  ...          3        6.0
# 9232          9232    20-May-2019  ...          3        6.0
# 9233          9233    21-May-2019  ...          3        6.0
# 9234          9234    22-May-2019  ...          3        6.0
# 9235          9235    23-May-2019  ...          3        6.0
# 9236          9236    24-May-2019  ...          3        6.0
# 9237          9237    27-May-2019  ...          3        6.0
# 9238          9238    28-May-2019  ...          3        6.0
# 9239          9239    29-May-2019  ...          3        6.0
# 9240          9240    30-May-2019  ...          3        6.0
# 9241          9241    31-May-2019  ...          3        6.0
#
# [9242 rows x 9 columns]

# %%
prediction_df.describe()
# Out:
#        Unnamed: 0     Date_num   Gdp_growth  Stable_gov  Gdp_class    Bank_rate
# count  1367.00000   1367.00000  1367.000000      1367.0     1367.0  1367.000000
# mean    683.00000  10107.50695     7.521646         1.0        3.0     5.750914
# std     394.76322    608.41189     0.248902         0.0        0.0     0.015097
# min       0.00000   9244.00000     7.110000         1.0        3.0     5.750000
# 25%     341.50000   9585.50000     7.450000         1.0        3.0     5.750000
# 50%     683.00000   9946.00000     7.730000         1.0        3.0     5.750000
# 75%    1024.50000  10629.00000     7.730000         1.0        3.0     5.750000
# max    1366.00000  11312.00000     7.740000         1.0        3.0     6.000000

# %%
plt.plot(sensex_df['Bank_rate'])

# %%
sensex_df['Gdp_band'] = pd.cut(sensex_df['Gdp_growth'],4)
sensex_df[['Gdp_band','Sensex']].groupby('Gdp_band').mean()
# Out:
#                        Sensex
# Gdp_band
# (-5.215, -1.36]    122.373049
# (-1.36, 2.48]     1873.750648
# (2.48, 6.32]      4863.335252
# (6.32, 10.16]    12962.120484

# %%
sensex_df.loc[(sensex_df['Gdp_growth']>-5.215) & (sensex_df['Gdp_growth']<=-1.36),'Gdp_class'] = 0
sensex_df.loc[(sensex_df['Gdp_growth']>-1.36) & (sensex_df['Gdp_growth']<=2.48),'Gdp_class'] = 1
sensex_df.loc[(sensex_df['Gdp_growth']>2.48) & (sensex_df['Gdp_growth']<=6.32),'Gdp_class'] = 2
sensex_df.loc[(sensex_df['Gdp_growth']>6.32) & (sensex_df['Gdp_growth']<=10.16),'Gdp_class'] = 3

prediction_df.loc[(prediction_df['Gdp_growth']>-5.215) & (prediction_df['Gdp_growth']<=-1.36),'Gdp_class'] = 0
prediction_df.loc[(prediction_df['Gdp_growth']>-1.36) & (prediction_df['Gdp_growth']<=2.48),'Gdp_class'] = 1
prediction_df.loc[(prediction_df['Gdp_growth']>2.48) & (prediction_df['Gdp_growth']<=6.32),'Gdp_class'] = 2
prediction_df.loc[(prediction_df['Gdp_growth']>6.32) & (prediction_df['Gdp_growth']<=10.16),'Gdp_class'] = 3

# %%
sensex_df['Gdp_class']= sensex_df['Gdp_class'].astype(int)
prediction_df['Gdp_class']= prediction_df['Gdp_class'].astype(int)

# %%
X=sensex_df[['Date_num','Gdp_class','Stable_gov','Bank_rate']]
y=sensex_df.Sensex

# %%
y
# Out:
# 0         124.15
# 1         122.85
# 2         123.52
# 3         124.18
# 4         124.30
# 5         125.01
# 6         125.93
# 7         128.22
# 8         126.24
# 9         125.98
# 10        126.14
# 11        126.67
# 12        126.75
# 13        124.81
# 14        124.67
# 15        125.36
# 16        125.78
# 17        127.02
# 18        126.73
# 19        125.84
# 20        125.80
# 21        124.93
# 22        124.77
# 23        124.64
# 24        123.12
# 25        122.23
# 26        122.63
# 27        123.93
# 28        124.59
# 29        124.10
#           ...
# 9212    39275.64
# 9213    39140.28
# 9214    38645.18
# 9215    38564.88
# 9216    39054.68
# 9217    38730.86
# 9218    39067.33
# 9219    39031.55
# 9220    38981.43
# 9221    38963.26
# 9222    38600.34
# 9223    38276.63
# 9224    37789.13
# 9225    37558.91
# 9226    37462.99
# 9227    37090.82
# 9228    37318.53
# 9229    37114.88
# 9230    37393.48
# 9231    37930.77
# 9232    39352.67
# 9233    38969.80
# 9234    39110.21
# 9235    38811.39
# 9236    39434.72
# 9237    39683.29
# 9238    39749.73
# 9239    39502.05
# 9240    39831.97
# 9241    39714.20
# Name: Sensex, Length: 9242, dtype: float64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state = 1)

# %%
X_train
# Out:
#       Date_num  Gdp_class  Stable_gov  Bank_rate
# 1885      1886          3           1      10.00
# 4580      4581          2           1       7.50
# 1102      1103          2           1      10.00
# 6307      6308          3           1       6.00
# 1748      1749          2           1      10.00
# 2684      2685          2           1      12.00
# 8343      8344          3           1       7.75
# 7279      7280          3           1       9.50
# 5000      5001          2           1       6.25
# 6381      6382          3           1       6.00
# 3668      3669          3           0      12.00
# 4683      4684          2           1       7.50
# 4719      4720          2           1       6.25
# 8883      8884          3           1       6.75
# 413        414          2           1       9.00
# 2651      2652          2           1      12.00
# 1190      1191          2           1      10.00
# 6105      6106          3           1       6.00
# 2562      2563          1           1      12.00
# 1040      1041          2           1      10.00
# 8033      8034          2           1       8.50
# 5508      5509          3           1       6.00
# 321        322          3           1       9.00
# 4846      4847          2           1       6.25
# 5814      5815          3           1       6.00
# 3933      3934          2           0      10.50
# 1817      1818          3           1      10.00
# 1075      1076          2           1      10.00
# 5981      5982          3           1       6.00
# 4017      4018          3           1       8.00
# ...        ...        ...         ...        ...
# 2877      2878          2           1      12.00
# 4415      4416          3           1       7.00
# 1031      1032          2           1      10.00
# 6121      6122          3           1       6.00
# 6285      6286          3           1       6.00
# 1110      1111          2           1      10.00
# 1888      1889          3           1      10.00
# 753        754          2           1      10.00
# 3049      3050          3           1      12.00
# 8151      8152          2           1       8.50
# 562        563          2           1      10.00
# 6542      6543          3           1       6.00
# 8093      8094          2           1       8.50
# 4764      4765          2           1       6.25
# 3562      3563          3           0      12.00
# 8444      8445          3           1       7.75
# 2516      2517          1           1      11.00
# 2962      2963          2           1      12.00
# 5374      5375          3           1       6.00
# 5396      5397          3           1       6.00
# 3462      3463          3           1      12.00
# 7751      7752          2           1       9.00
# 4225      4226          3           1       7.00
# 144        145          0           0       9.00
# 5056      5057          2           1       6.25
# 2895      2896          2           1      12.00
# 7813      7814          2           1       9.00
# 905        906          3           1      10.00
# 5192      5193          2           1       6.00
# 235        236          3           1       9.00
#
# [6931 rows x 4 columns]

# %%
X_train,X_val,y_train,y_val = train_test_split(X_train,y_train,random_state = 1)

# %%
def norm(x):
  return (x - X_train.mean()) / X_train.std()
normed_X_train = norm(X_train)
normed_X_val = norm(X_val)
normed_X_test = norm(X_test)

# %%
def norm1(x):
  return (x-y_train.mean()) / y_train.std()
normed_y_train = norm1(y_train)
normed_y_val = norm1(y_val)
normed_y_test = norm1(y_test)

# %%
def build_model():
  model = keras.Sequential([
     layers.Dense(64,kernel_regularizer=keras.regularizers.l2(0.001), activation=tf.nn.relu, input_shape=[len(normed_X_train.keys())]),
     layers.Dense(64,kernel_regularizer=keras.regularizers.l2(0.001), activation=tf.nn.relu),  
     layers.Dense(1)
  ])
  optimizer = tf.keras.optimizers.RMSprop(0.001)

  model.compile(loss='mean_squared_error',
                optimizer=optimizer,
                metrics=['mean_absolute_error', 'mean_squared_error'])
  return model

# %%
model = build_model()

# %%
example_batch = normed_X_train[:10]
example_result = model.predict(example_batch)
example_result
# Out:
# array([[-0.0186277 ],
#        [-0.2170778 ],
#        [-0.34946364],
#        [-0.02924862],
#        [-0.08287363],
#        [-0.2060249 ],
#        [ 0.03481282],
#        [ 0.03257897],
#        [-0.08255726],
#        [-0.20877641]], dtype=float32)

# %%
# Display training progress by printing a single dot for each completed epoch
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')

EPOCHS = 1000

history = model.fit(
  normed_X_train, normed_y_train,
  epochs=EPOCHS, validation_split = 0.2, verbose=0,
  callbacks=[PrintDot()],
   batch_size=256,
    validation_data=(normed_X_val,normed_y_val)
 )
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#          loss  mean_absolute_error  ...  val_mean_squared_error  epoch
# 995  0.015639             0.063921  ...                0.010064    995
# 996  0.015917             0.064877  ...                0.010132    996
# 997  0.016158             0.066095  ...                0.010172    997
# 998  0.015673             0.063570  ...                0.011235    998
# 999  0.016235             0.065699  ...                0.011118    999
#
# [5 rows x 7 columns]

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch
  
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error [MPG]')
  plt.plot(hist['epoch'], hist['mean_absolute_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_absolute_error'],
           label = 'Val Error')

  plt.legend()
  
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error [$MPG^2$]')
  plt.plot(hist['epoch'], hist['mean_squared_error'],
           label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_squared_error'],
           label = 'Val Error')

  plt.legend()
  plt.show()


plot_history(history)

# %%
val_predictions = model.predict(norm(X_test)).flatten()

plt.scatter(y_test, val_predictions)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
plt.axis('equal')
plt.axis('square')
# Out:
# (-1871.2573566308247,
#  41817.847356630824,
#  -1.1340707930179095,
#  43687.97064246863)

# %%
test_predictions = model.predict(norm(X)).flatten()

# %%
test_predictions = test_predictions*y_train.std() + y_train.mean()

# %%
plt.plot(y),plt.plot(test_predictions)
# Out:
# ([<matplotlib.lines.Line2D at 0x7fe9219303c8>],
#  [<matplotlib.lines.Line2D at 0x7fe921930748>])

# %%
loss,mae,mse = model.evaluate(normed_X_test,normed_y_test)
# Out:
# 2311/2311 [==============================] - 0s 29us/sample - loss: 0.0166 - mean_absolute_error: 0.0661 - mean_squared_error: 0.0129

# %%
past_sensex = pd.DataFrame({
        "Day": sensex_df['Date'],
        "GDP_class":sensex_df['Gdp_class'],
        "Stable_Gov":sensex_df['Stable_gov'],
        "PredictedSensex":test_predictions,
        "Real_Sensex":sensex_df['Sensex'],
        "Percentage_error": ((test_predictions - sensex_df['Sensex'])/sensex_df['Sensex'])*100
})

# %%
past_sensex
# Out:
#                 Day  GDP_class  ...  Real_Sensex  Percentage_error
# 0      3-April-1979          0  ...       124.15       -288.003423
# 1      4-April-1979          0  ...       122.85       -289.348195
# 2      6-April-1979          0  ...       123.52       -287.680734
# 3      7-April-1979          0  ...       124.18       -286.044672
# 4      9-April-1979          0  ...       124.30       -285.227116
# 5     11-April-1979          0  ...       125.01       -283.541567
# 6     12-April-1979          0  ...       125.93       -281.570987
# 7     14-April-1979          0  ...       128.22       -277.709698
# 8     17-April-1979          0  ...       126.24       -279.870373
# 9     18-April-1979          0  ...       125.98       -279.612928
# 10    19-April-1979          0  ...       126.14       -278.755686
# 11    20-April-1979          0  ...       126.67       -277.383284
# 12    21-April-1979          0  ...       126.75       -276.644940
# 13    23-April-1979          0  ...       124.81       -278.756867
# 14    24-April-1979          0  ...       124.67       -278.321550
# 15    25-April-1979          0  ...       125.36       -276.709047
# 16    26-April-1979          0  ...       125.78       -275.488545
# 17    27-April-1979          0  ...       127.02       -273.151097
# 18       2-May-1979          0  ...       126.73       -272.922379
# 19       3-May-1979          0  ...       125.84       -273.515228
# 20       4-May-1979          0  ...       125.80       -272.941611
# 21       5-May-1979          0  ...       124.93       -273.511229
# 22       7-May-1979          0  ...       124.77       -273.098188
# 23       8-May-1979          0  ...       124.64       -272.643306
# 24       9-May-1979          0  ...       123.12       -274.131437
# 25      10-May-1979          0  ...       122.23       -274.751397
# 26      11-May-1979          0  ...       122.63       -273.534750
# 27      15-May-1979          0  ...       123.93       -271.075342
# 28      16-May-1979          0  ...       124.59       -269.532630
# 29      17-May-1979          0  ...       124.10       -269.563041
# ...             ...        ...  ...          ...               ...
# 9212  16-April-2019          3  ...     39275.64         -3.194418
# 9213  18-April-2019          3  ...     39140.28         -2.832906
# 9214  22-April-2019          3  ...     38645.18         -1.560977
# 9215  23-April-2019          3  ...     38564.88         -1.328892
# 9216  24-April-2019          3  ...     39054.68         -2.539579
# 9217  25-April-2019          3  ...     38730.86         -1.697725
# 9218  26-April-2019          3  ...     39067.33         -2.517574
# 9219  30-April-2019          3  ...     39031.55         -2.401401
# 9220     2-May-2019          3  ...     38981.43         -2.249089
# 9221     3-May-2019          3  ...     38963.26         -2.176655
# 9222     6-May-2019          3  ...     38600.34         -1.229821
# 9223     7-May-2019          3  ...     38276.63         -0.367180
# 9224     8-May-2019          3  ...     37789.13          0.945819
# 9225     9-May-2019          3  ...     37558.91          1.592426
# 9226    10-May-2019          3  ...     37462.99          1.880476
# 9227    13-May-2019          3  ...     37090.82          2.930940
# 9228    14-May-2019          3  ...     37318.53          2.330908
# 9229    15-May-2019          3  ...     37114.88          2.920595
# 9230    16-May-2019          3  ...     37393.48          2.181761
# 9231    17-May-2019          3  ...     37930.77          0.761944
# 9232    20-May-2019          3  ...     39352.67         -2.852238
# 9233    21-May-2019          3  ...     38969.80         -1.870938
# 9234    22-May-2019          3  ...     39110.21         -2.196475
# 9235    23-May-2019          3  ...     38811.39         -1.416504
# 9236    24-May-2019          3  ...     39434.72         -2.948240
# 9237    27-May-2019          3  ...     39683.29         -3.529806
# 9238    28-May-2019          3  ...     39749.73         -3.664725
# 9239    29-May-2019          3  ...     39502.05         -3.034216
# 9240    30-May-2019          3  ...     39831.97         -3.811091
# 9241    31-May-2019          3  ...     39714.20         -3.499518
#
# [9242 rows x 6 columns]

# %%
past_sensex.describe()
# Out:
#          GDP_class   Stable_Gov  ...   Real_Sensex  Percentage_error
# count  9242.000000  9242.000000  ...   9242.000000       9242.000000
# mean      2.503246     0.899372  ...   9334.863178        -21.446606
# std       0.664495     0.300851  ...  10348.341961         53.478312
# min       0.000000     0.000000  ...    113.280000       -289.348195
# 25%       2.000000     1.000000  ...   1040.585000        -20.140871
# 50%       3.000000     1.000000  ...   3933.215000         -5.286270
# 75%       3.000000     1.000000  ...  16949.657500          1.473648
# max       3.000000     1.000000  ...  39831.970000         72.863518
#
# [8 rows x 5 columns]

# %%
past_sensex
# Out:
#                 Day  GDP_class  ...  Real_Sensex  Percentage_error
# 0      3-April-1979          0  ...       124.15       -288.003423
# 1      4-April-1979          0  ...       122.85       -289.348195
# 2      6-April-1979          0  ...       123.52       -287.680734
# 3      7-April-1979          0  ...       124.18       -286.044672
# 4      9-April-1979          0  ...       124.30       -285.227116
# 5     11-April-1979          0  ...       125.01       -283.541567
# 6     12-April-1979          0  ...       125.93       -281.570987
# 7     14-April-1979          0  ...       128.22       -277.709698
# 8     17-April-1979          0  ...       126.24       -279.870373
# 9     18-April-1979          0  ...       125.98       -279.612928
# 10    19-April-1979          0  ...       126.14       -278.755686
# 11    20-April-1979          0  ...       126.67       -277.383284
# 12    21-April-1979          0  ...       126.75       -276.644940
# 13    23-April-1979          0  ...       124.81       -278.756867
# 14    24-April-1979          0  ...       124.67       -278.321550
# 15    25-April-1979          0  ...       125.36       -276.709047
# 16    26-April-1979          0  ...       125.78       -275.488545
# 17    27-April-1979          0  ...       127.02       -273.151097
# 18       2-May-1979          0  ...       126.73       -272.922379
# 19       3-May-1979          0  ...       125.84       -273.515228
# 20       4-May-1979          0  ...       125.80       -272.941611
# 21       5-May-1979          0  ...       124.93       -273.511229
# 22       7-May-1979          0  ...       124.77       -273.098188
# 23       8-May-1979          0  ...       124.64       -272.643306
# 24       9-May-1979          0  ...       123.12       -274.131437
# 25      10-May-1979          0  ...       122.23       -274.751397
# 26      11-May-1979          0  ...       122.63       -273.534750
# 27      15-May-1979          0  ...       123.93       -271.075342
# 28      16-May-1979          0  ...       124.59       -269.532630
# 29      17-May-1979          0  ...       124.10       -269.563041
# ...             ...        ...  ...          ...               ...
# 9212  16-April-2019          3  ...     39275.64         -3.194418
# 9213  18-April-2019          3  ...     39140.28         -2.832906
# 9214  22-April-2019          3  ...     38645.18         -1.560977
# 9215  23-April-2019          3  ...     38564.88         -1.328892
# 9216  24-April-2019          3  ...     39054.68         -2.539579
# 9217  25-April-2019          3  ...     38730.86         -1.697725
# 9218  26-April-2019          3  ...     39067.33         -2.517574
# 9219  30-April-2019          3  ...     39031.55         -2.401401
# 9220     2-May-2019          3  ...     38981.43         -2.249089
# 9221     3-May-2019          3  ...     38963.26         -2.176655
# 9222     6-May-2019          3  ...     38600.34         -1.229821
# 9223     7-May-2019          3  ...     38276.63         -0.367180
# 9224     8-May-2019          3  ...     37789.13          0.945819
# 9225     9-May-2019          3  ...     37558.91          1.592426
# 9226    10-May-2019          3  ...     37462.99          1.880476
# 9227    13-May-2019          3  ...     37090.82          2.930940
# 9228    14-May-2019          3  ...     37318.53          2.330908
# 9229    15-May-2019          3  ...     37114.88          2.920595
# 9230    16-May-2019          3  ...     37393.48          2.181761
# 9231    17-May-2019          3  ...     37930.77          0.761944
# 9232    20-May-2019          3  ...     39352.67         -2.852238
# 9233    21-May-2019          3  ...     38969.80         -1.870938
# 9234    22-May-2019          3  ...     39110.21         -2.196475
# 9235    23-May-2019          3  ...     38811.39         -1.416504
# 9236    24-May-2019          3  ...     39434.72         -2.948240
# 9237    27-May-2019          3  ...     39683.29         -3.529806
# 9238    28-May-2019          3  ...     39749.73         -3.664725
# 9239    29-May-2019          3  ...     39502.05         -3.034216
# 9240    30-May-2019          3  ...     39831.97         -3.811091
# 9241    31-May-2019          3  ...     39714.20         -3.499518
#
# [9242 rows x 6 columns]

# %%
hist['mean_absolute_error']
# Out:
# 0      0.477720
# 1      0.223020
# 2      0.142315
# 3      0.122860
# 4      0.114945
# 5      0.113936
# 6      0.109256
# 7      0.108431
# 8      0.105328
# 9      0.104450
# 10     0.102054
# 11     0.102392
# 12     0.100541
# 13     0.098132
# 14     0.101927
# 15     0.098023
# 16     0.099140
# 17     0.097551
# 18     0.098031
# 19     0.097245
# 20     0.095465
# 21     0.096873
# 22     0.094803
# 23     0.094960
# 24     0.094565
# 25     0.094333
# 26     0.094948
# 27     0.093939
# 28     0.094260
# 29     0.092915
#          ...
# 970    0.066329
# 971    0.064667
# 972    0.066862
# 973    0.064935
# 974    0.065137
# 975    0.063287
# 976    0.064364
# 977    0.065777
# 978    0.064361
# 979    0.064742
# 980    0.065640
# 981    0.063646
# 982    0.064209
# 983    0.064804
# 984    0.065646
# 985    0.064660
# 986    0.064472
# 987    0.063318
# 988    0.063988
# 989    0.066098
# 990    0.065322
# 991    0.065975
# 992    0.066059
# 993    0.062897
# 994    0.066429
# 995    0.063921
# 996    0.064877
# 997    0.066095
# 998    0.063570
# 999    0.065699
# Name: mean_absolute_error, Length: 1000, dtype: float64

# %%
prediction_df
# Out:
#       Unnamed: 0  Date_num  Gdp_growth  Stable_gov  Gdp_class  Bank_rate
# 0              0      9244        7.11           1          3       6.00
# 1              1      9245        7.11           1          3       6.00
# 2              2      9246        7.11           1          3       6.00
# 3              3      9247        7.11           1          3       6.00
# 4              4      9248        7.11           1          3       6.00
# 5              5      9249        7.11           1          3       5.75
# 6              6      9250        7.11           1          3       5.75
# 7              7      9251        7.11           1          3       5.75
# 8              8      9252        7.11           1          3       5.75
# 9              9      9253        7.11           1          3       5.75
# 10            10      9254        7.11           1          3       5.75
# 11            11      9255        7.11           1          3       5.75
# 12            12      9256        7.11           1          3       5.75
# 13            13      9257        7.11           1          3       5.75
# 14            14      9258        7.11           1          3       5.75
# 15            15      9259        7.11           1          3       5.75
# 16            16      9260        7.11           1          3       5.75
# 17            17      9261        7.11           1          3       5.75
# 18            18      9262        7.11           1          3       5.75
# 19            19      9263        7.11           1          3       5.75
# 20            20      9264        7.11           1          3       5.75
# 21            21      9265        7.11           1          3       5.75
# 22            22      9266        7.11           1          3       5.75
# 23            23      9267        7.11           1          3       5.75
# 24            24      9268        7.11           1          3       5.75
# 25            25      9269        7.11           1          3       5.75
# 26            26      9270        7.11           1          3       5.75
# 27            27      9271        7.11           1          3       5.75
# 28            28      9272        7.11           1          3       5.75
# 29            29      9273        7.11           1          3       5.75
# ...          ...       ...         ...         ...        ...        ...
# 1337        1337     11254        7.73           1          3       5.75
# 1338        1338     11256        7.73           1          3       5.75
# 1339        1339     11258        7.73           1          3       5.75
# 1340        1340     11260        7.73           1          3       5.75
# 1341        1341     11262        7.73           1          3       5.75
# 1342        1342     11264        7.73           1          3       5.75
# 1343        1343     11266        7.73           1          3       5.75
# 1344        1344     11268        7.73           1          3       5.75
# 1345        1345     11270        7.73           1          3       5.75
# 1346        1346     11272        7.73           1          3       5.75
# 1347        1347     11274        7.73           1          3       5.75
# 1348        1348     11276        7.73           1          3       5.75
# 1349        1349     11278        7.73           1          3       5.75
# 1350        1350     11280        7.73           1          3       5.75
# 1351        1351     11282        7.73           1          3       5.75
# 1352        1352     11284        7.73           1          3       5.75
# 1353        1353     11286        7.73           1          3       5.75
# 1354        1354     11288        7.73           1          3       5.75
# 1355        1355     11290        7.73           1          3       5.75
# 1356        1356     11292        7.73           1          3       5.75
# 1357        1357     11294        7.73           1          3       5.75
# 1358        1358     11296        7.73           1          3       5.75
# 1359        1359     11298        7.73           1          3       5.75
# 1360        1360     11300        7.73           1          3       5.75
# 1361        1361     11302        7.73           1          3       5.75
# 1362        1362     11304        7.73           1          3       5.75
# 1363        1363     11306        7.73           1          3       5.75
# 1364        1364     11308        7.73           1          3       5.75
# 1365        1365     11310        7.73           1          3       5.75
# 1366        1366     11312        7.73           1          3       5.75
#
# [1367 rows x 6 columns]

# %%
X_future=prediction_df[['Date_num','Gdp_class','Stable_gov','Bank_rate']]

# %%
X_future_normed = norm(X_future)

# %%
y_future_normed = model.predict(X_future_normed)

# %%
y_future_normed = y_future_normed * y_test.std() + y_test.mean()

# %%
y_future_normed
# Out:
# array([[38175.906],
#        [38186.32 ],
#        [38196.74 ],
#        ...,
#        [59252.652],
#        [59272.426],
#        [59292.203]], dtype=float32)

# %%
plt.plot(y_future_normed)

# %%
X_full = pd.concat([X,X_future])

# %%
X_full_normed = norm(X_full)

# %%
y_full_normed = model.predict(X_full_normed)

# %%
y_full = y_full_normed * y_train.std() + y_train.mean()

# %%
plt.plot(y_full)
